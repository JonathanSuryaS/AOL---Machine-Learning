# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
heart_failure_clinical_records = fetch_ucirepo(id=519) 
  
# data (as pandas dataframes) 
X = heart_failure_clinical_records.data.features 
y = heart_failure_clinical_records.data.targets 
  
# metadata 
print(heart_failure_clinical_records.metadata) 
  
# variable information 
print(heart_failure_clinical_records.variables)
# Out:
# {'uci_id': 519, 'name': 'Heart Failure Clinical Records', 'repository_url': 'https://archive.ics.uci.edu/dataset/519/heart+failure+clinical+records', 'data_url': 'https://archive.ics.uci.edu/static/public/519/data.csv', 'abstract': 'This dataset contains the medical records of 299 patients who had heart failure, collected during their follow-up period, where each patient profile has 13 clinical features.', 'area': 'Health and Medicine', 'tasks': ['Classification', 'Regression', 'Clustering'], 'characteristics': ['Multivariate'], 'num_instances': 299, 'num_features': 12, 'feature_types': ['Integer', 'Real'], 'demographics': ['Age', 'Sex'], 'target_col': ['death_event'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2020, 'last_updated': 'Mon Feb 26 2024', 'dataset_doi': '10.24432/C5Z89R', 'creators': [], 'intro_paper': {'title': 'Machine learning can predict survival of patients with heart failure from serum creatinine and ej
# ...

# %% [markdown]
# ## Data

# %%
data = X
data['death_event'] = y
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %% [markdown]
# ## Statistical Summary of data

# %%
data.describe().T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.833893     11.894809     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# ...

# %% [markdown]
# ## Data Types and NULL Entries

# %% [markdown]
# ### Data Types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  death_event               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# ### NULL Entry

# %%
data.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# death_event                 0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Relationship between Features

# %% [markdown]
# ### Death Events -> Target

# %%
fig, ax = plt.subplots(1, 2, figsize = (18,8))
data['death_event'].value_counts().plot(kind = 'pie', ax = ax[0], autopct = '%1.1f%%', shadow = True, explode= [0, 0.1])
ax[0].set_title('Death events distribution (Pie Chart)')
sns.countplot(data = data, x = 'death_event', hue = 'death_event')
ax[1].set_title('Death events distribution (Count plot)')
plt.show()

# %% [markdown]
# The graph above tell us the distribution between target features (Death events) by Pie chart and Countplot, where as we can see, the data is not balanced, as death_event == 0, is mostly dominate the distribution.

# %% [markdown]
# ### Age
# Age of the patient (years)

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
sns.histplot(data = data, x = 'age', ax = ax[0], kde = True, bins = 10)
ax[0].set_title('Age Distribution (Histogram)')
sns.boxplot(data = data, x = 'age')
plt.show()

# %% [markdown]
# Based on the graph, we could see that Age perform a normal distribution, as there is no outlier available in the boxplot

# %%
plt.figure(figsize=(18, 8))
sns.lineplot(data = data, x = 'age', y = 'death_event')
plt.title('Lineplot Age vs Death')
plt.show()

# %%
plt.figure(figsize=(18, 8))
sns.histplot(data = data, x = 'age', hue = 'death_event', kde = True)
plt.title('Histogram Age vs Death Event')
plt.show()

# %% [markdown]
# Based from the graph above, we can tell that while the frequency of death events is mostly happened at age above 80 y.o, it still have potential to attack at person with lower younger age.

# %% [markdown]
# ### Anaemia
# Decrease of red blood cells or hemoglobin

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
data['anaemia'].value_counts().plot(kind = 'pie', ax = ax[0], autopct = '%1.1f%%', shadow = True, explode = [0, 0.1])
ax[0].set_title('Anaemia distribution (Pie Chart)')
ax[0].set_ylabel('')
sns.pointplot(data = data, x ='anaemia', y = 'death_event')
ax[1].set_title('Pointplot Anaemia vs Death Event')
plt.show()

# %% [markdown]
# Based on the graph, patient who have anaemia, decrease of Hemoglobin or Red Blood Cells have a higher chance for death_events

# %%
plt.figure(figsize= (18, 8))
sns.histplot(data = data, x = 'age', hue = 'anaemia', kde = True)
plt.title('Histogram Age vs Anaemia')
plt.show()

# %% [markdown]
# Here we can see that at age around 60 y.o, the chance of having anaemia is slighlty bigger and grrows bigger for age around 85+ y.o

# %% [markdown]
# ### creatinine_phosphokinase
# level of the CPK enzyme in the blood (mcg/L)

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
sns.histplot(data = data, x = 'creatinine_phosphokinase', ax = ax[0], bins = 40, kde = True)
ax[0].set_title('Creatinine Phosphokinase Distribution (Histogram)')
ax[1].set_title('Creatinine Phosphokinase Distribution (Boxplot)')
sns.boxplot(data = data, x = 'creatinine_phosphokinase')
plt.show()

# %% [markdown]
# We can see that creatinine phosphokinase perform right skewed distribution as there is many outliers for this data

# %%
plt.figure(figsize=(18, 8))
sns.histplot(data = data, x = 'creatinine_phosphokinase',  bins = 40, kde = True, hue = 'death_event')
plt.show()

# %% [markdown]
# For creatinine phosphokinase above 6000, it seems that the death events is sliglty higher

# %%
plt.figure(figsize=(18, 10))
sns.scatterplot(data = data, x = 'age', y = 'creatinine_phosphokinase')
plt.title('Scatterplot Age vs Ceratinine Phospokinase')
plt.show()

# %% [markdown]
# However, based on data there is no pattern we can look at creatinine phosphokinase and age. That means each patient with their age has their own creatine phosphokinase

# %% [markdown]
# ### Diabetes

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
data['diabetes'].value_counts().plot(kind = 'pie', ax = ax[0], autopct = '%1.1f%%', shadow = True, explode = [0, 0.1])
ax[0].set_title('Diabetes Distribution (Pie Chart)')
ax[0].set_ylabel('')
sns.lineplot(data= data, x = 'diabetes', y = 'death_event')
ax[1].set_title('Lineplot Diabetes vs Death event')
plt.show()

# %% [markdown]
# Based on the graph, we could see that whether patient have diabetes or not, the chance to have death events has very small difference.

# %% [markdown]
# ### Ejection Fraction
# percentage of blood leaving the heart at each contraction

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
sns.histplot(data = data, x = 'ejection_fraction', ax = ax[0], kde = True, bins = 10)
ax[0].set_title('Ejection Fraction Distribution (Histogram)')
ax[1].set_title('Ejection Fraction Distribution (Box Plot)')
sns.boxplot(data = data, x = 'ejection_fraction')
plt.show()

# %% [markdown]
# Eejction Fraction performed a normal distribution, where as we can see it has very small outliers from the boxplot

# %%
plt.figure(figsize=(18, 10))
sns.lineplot(data = data, x ='ejection_fraction', y = 'death_event')
plt.title('Ejection Fraction vs Death Event')
plt.show()

# %% [markdown]
# From the graph, we can see that the higher ejection fraction rate is the lower death event chance untill 60%, where it gradually increase and lower again

# %% [markdown]
# ### high_blood_pressure
# If the patient have hypertension

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
data['high_blood_pressure'].value_counts().plot(kind = 'pie', ax = ax[0], shadow = True, autopct = '%1.1f%%', explode = [0, 0.1])
ax[0].set_title('High Blood Pressure Distribution (Pie Chart)')
ax[0].set_ylabel('')
ax[1].set_title('Pointplot High Blood Pressure vs Death Event')
sns.pointplot(data = data, x = 'high_blood_pressure', y = 'death_event')
plt.show()

# %% [markdown]
# From the graph, we can see that patient that have hypertension on their blood has a higher chance to receive death event

# %%
plt.figure(figsize=(18, 8))
sns.lineplot(data = data, x = 'age',  y = 'high_blood_pressure')
plt.show()

# %% [markdown]
# Highblood Pressure doesnt have any pattern related to age, as where we can see, there is no pattern we can take from this graph.

# %% [markdown]
# ### Platelets
# platelets in the blood (kiloplatelets/mL)

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
sns.histplot(data = data, x = 'platelets', ax = ax[0], kde = True)
sns.boxplot(data =data, x = 'platelets')
ax[0].set_title('Platelets Distribution (Histogram)')
ax[1].set_title('Platelets Distribution (Box Plot)')
plt.show()

# %% [markdown]
# From the histogram shape, platelets perfrom a normal distribution, even though there is an outlier for this feature

# %%
plt.figure(figsize=(18, 8))
sns.histplot(data = data, x = 'platelets',  bins = 40, kde = True, hue = 'death_event')
plt.title('Platelet vs death Event')
plt.show()

# %% [markdown]
# We can see here while mostly platelet does not highly affect death events.

# %% [markdown]
# ### serum_creatinine
# level of serum creatinine in the blood (mg/dL)

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
sns.histplot(data = data, x = 'serum_creatinine', ax = ax[0], kde = True)
sns.boxplot(data =data, x = 'serum_creatinine')
ax[0].set_title('Serum Creatinine Distribution (Histogram)')
ax[1].set_title('Serum Creatinine (Box Plot)')
plt.show()

# %% [markdown]
# Serum creatinine perform a right skewed distribution, as there is many outliers for this data

# %%
plt.figure(figsize=(18, 8))
sns.histplot(data = data, x = 'serum_creatinine',  bins = 40, kde = True, hue = 'death_event')
plt.title('Serum Creatinine vs death Event')
plt.show()

# %% [markdown]
# As for serum creatinine, for serum creatinine > 2 has higher chance for death events

# %% [markdown]
# ### serum_sodium
# level of serum sodium in the blood (mEq/L)

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
sns.histplot(data = data, x = 'serum_sodium', ax = ax[0], kde = True)
sns.boxplot(data =data, x = 'serum_sodium')
ax[0].set_title('Serum Creatinine Distribution (Histogram)')
ax[1].set_title('Serum Creatinine (Box Plot)')
plt.show()

# %% [markdown]
# serum_sodium performed a normal distribution, as seen from the shape of it, and it does not contain many outliers.

# %%
plt.figure(figsize=(18, 8))
sns.histplot(data = data, x = 'serum_sodium',  bins = 40, kde = True, hue = 'death_event')
plt.title('Serum Sodium vs death Event')
plt.show()

# %% [markdown]
# As for Serum Sodium, for Serum Sodium < 130 has higher chance for death events
