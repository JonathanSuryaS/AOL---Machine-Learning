# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:lightblue;font-family:sans-serif;color:#FFffxx;font-size:250%;text-align:center;border-radius:15px 15px;"> 👨‍💻<topic> Prediction Analysis 📊🔍 </p>

# %% [markdown]
# # Libraries 🤖

# %% [markdown]
# <img src="library.jpg" alt="Library" width="500" height="300"><br>
# ## Commonly Used Library for Machine Learning:<br>
#   <ul style = " font-family: 'Segoe UI'; font-size: 20px;">
#             <li>Pandas</li>
#             <li>Numpy</li>
#             <li>Matplotlib.pyplot</li>
#             <li>Seaborn</li>
#         </ul>
#     </p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data

# %% [markdown]
# <!-- <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:lightblue;font-family:sans-serif;color:#FFffxx;font-size:250%;text-align:center;border-radius:15px 15px;"> 👨‍💻 Car Data for Analysis 📊🔍 </p>
# <img src="carHeader.png" alt="Library" width="1000" height="500"><br> -->

# %%
data = pd.read_csv('train.csv')
data.head(20)
# Out:
#    Customer ID               Name Gender  Age  Income (USD) Income Stability  \
# 0      C-36995   Frederica Shealy      F   56       1933.05              Low
# 1      C-33999  America Calderone      M   32       4952.91              Low
# 2       C-3770      Rosetta Verne      F   65        988.19             High
# 3      C-26480         Zoe Chitty      F   65           NaN             High
# 4      C-23459       Afton Venema      F   31       2614.77              Low
# 5      C-17688     Polly Crumpler      F   60       1234.92              Low
# 6      C-23855   Nathalie Olivier      M   43       2361.56              Low
# 7      C-11006   Clarinda Montana      F   45           NaN              Low
# 8      C-26934       Kenny Ankrom      F   38       1296.07              Low
# 9      C-24944     Barbie Goetsch      M   18       1546.17              Low
# 10     C-40801       Laree Staton      M   18       2416.86              Low
# ...

# %% [markdown]
# ## Data Info

# %% [markdown]
# ### Statistical Summary of data

# %%
data.describe()
# Out:
#                 Age  Income (USD)  Loan Amount Request (USD)  \
# count  30000.000000  2.542400e+04               30000.000000
# mean      40.092300  2.630574e+03               88826.333855
# std       16.045129  1.126272e+04               59536.949605
# min       18.000000  3.777000e+02                6048.240000
# 25%       25.000000  1.650457e+03               41177.755000
# 50%       40.000000  2.222435e+03               75128.075000
# 75%       55.000000  3.090593e+03              119964.605000
# max       65.000000  1.777460e+06              621497.820000
#
#        Current Loan Expenses (USD)    Dependents  Credit Score  \
# count                 29828.000000  27507.000000  28297.000000
# mean                    400.936876      2.253027    739.885381
# std                     242.545375      0.951162     72.163846
# min                    -999.000000      1.000000    580.000000
# 25%                     247.667500      2.000000    681.880000
# ...

# %% [markdown]
# ### Null and Data types info

# %% [markdown]
# #### NULL

# %%
data.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                           53
# Age                               0
# Income (USD)                   4576
# Income Stability               1683
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %% [markdown]
# #### Data Types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  30000 non-null  object
#  1   Name                         30000 non-null  object
#  2   Gender                       29947 non-null  object
#  3   Age                          30000 non-null  int64
#  4   Income (USD)                 25424 non-null  float64
#  5   Income Stability             28317 non-null  object
#  6   Profession                   30000 non-null  object
#  7   Type of Employment           22730 non-null  object
#  8   Location                     30000 non-null  object
#  9   Loan Amount Request (USD)    30000 non-null  float64
#  10  Current Loan Expenses (USD)  29828 non-null  float64
#  11  Expense Type 1               30000 non-null  object
#  12  Expense Type 2               30000 non-null  object
# ...

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist" style="display: flex; flex-direction: column; justify-content: center; align-items: center; background-color: lightblue; padding: 5px; border-radius: 15px; margin: 0; height: 100px;">
#     <p style="font-family: sans-serif; color: #FFffxx; font-size: 250%; text-align: center; margin: 0;">👨‍💻 Exploratory Data Analysis (EDA) 📊🔍</p>
# </div>

# %% [markdown]
# ## Relationship between Features

# %% [markdown]
# ### Loan Sanction Amount  (USD) Distribution -> Target Feature

# %% [markdown]
# <img src = 'dist.png' style = 'width:1000px'>

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
sns.histplot(data = data, x ='Loan Sanction Amount (USD)', bins = 30, kde = True, ax = ax[0])
ax[0].set_title('Histogram Distribution of Loan Sanction Amount (USD)')
ax[1].set_title('BoxPlot Distribution of Loan Sanction Amount (USD)')
sns.boxplot(data = data, x = 'Loan Sanction Amount (USD)')
plt.show()

# %% [markdown]
# Based on the graph, we can see <b>Loan Sanction Amount(USD) </b>is <b> Positively (rigt) skewed distribution </b> and has many outliers from the boxplot.<br>
# Because some data have their Loan Sanction Amount (USD) missing, we need to drop it because we could not make an assumption of the target result

# %%
data.dropna(subset=['Loan Sanction Amount (USD)'], inplace = True)

# %% [markdown]
# ### ID & Name

# %%
data['Customer ID'].value_counts()
# Out:
# Customer ID
# C-36995    1
# C-20856    1
# C-46847    1
# C-3319     1
# C-34530    1
#           ..
# C-22733    1
# C-24853    1
# C-24668    1
# C-41665    1
# C-33003    1
# Name: count, Length: 29660, dtype: int64

# %%
data['Name'].value_counts()
# Out:
# Name
# Frederica Shealy       1
# Rebecka Pietrzak       1
# Katelin Hollifield     1
# Albertina Lucarelli    1
# Necole Weatherbee      1
#                       ..
# Karlyn Harbin          1
# Sherwood Denker        1
# Odessa Morgenstern     1
# Nicki Vancleve         1
# Bridget Garibaldi      1
# Name: count, Length: 29660, dtype: int64

# %% [markdown]
# CustomerID and Name only <b>represent the rows</b > within the dataset, thus we do not need it in our Machine Learning Prediction.

# %%
data.drop(columns=['Customer ID', 'Name'], inplace = True)

# %% [markdown]
# ### Gender

# %%
fig, ax = plt.subplots(1,2 , figsize = (18, 8))
data['Gender'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%', ax = ax[0])
sns.pointplot(data = data, x ='Gender', y = 'Loan Sanction Amount (USD)',ax = ax[1])
ax[1].set_title('Loan Sanction Amount by Gender')
ax[0].set_title('Distribution of Gender')
plt.show()

# %% [markdown]
# From the graph, we can see that while many Customers are male, the Loan Sanction Amount is slightly bigger from Female

# %% [markdown]
# ### Age

# %%
fig, ax = plt.subplots(1, 2, figsize =(18, 8))
sns.histplot(data = data, x = 'Age', ax = ax[0])
sns.boxplot(data = data, x ='Age')
plt.show()

# %% [markdown]
# Our customer has mean age of around 40- with the youngest one around 25 and the oldest are around 55, we also got Binomial Distribution from the age

# %% [markdown]
# ### Income & Income Stability

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
sns.boxplot(data = data, x = 'Income (USD)', ax = ax[0], log_scale=True)

income = np.log(data['Income (USD)'])
loan = data['Loan Amount Request (USD)']
ax[0].set_title('Boxplot Distribution of Income (USD)')
ax[1].scatter(x = income, y = loan)
plt.xlabel('Log of Income (USD)')
plt.ylabel('Loan Amount Requested (USD)')
plt.title('Logarithmic Scaling of Income vs Loan Amount')

plt.show()

# %% [markdown]
# With Log_Scale we compresses larger values more than smaller values. For example, the difference between 1000 and 10000 might look the same as the difference between 1 and 10 on a log scale, even though the original difference is much larger for the former.<br>
# Based on the graph, we can see that Income has a lot of Outliers, and with Sccatter plot corresponding to Loan Amount Requested

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
sns.barplot(data = data, x = 'Income Stability', y = 'Income (USD)', ax = ax[0])
sns.pointplot(data = data, x= 'Income Stability', y = 'Loan Sanction Amount (USD)')
ax[0].set_title('Income Stability with Income Amount')
ax[1].set_title('Income Stability with Loan Amoun Sanction')
plt.show()

# %% [markdown]
# We can see that person with low income stability have  higher Income, however The one with High Income Stability Has greater chance to receive higher Amount of Loan Sanction

# %% [markdown]
# ### Profession & Type of Employment

# %%
data['Profession'].value_counts()
# Out:
# Profession
# Working                 16739
# Commercial associate     7863
# Pensioner                2718
# State servant            2334
# Unemployed                  2
# Businessman                 2
# Student                     1
# Maternity leave             1
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(1,2, figsize = (18, 8))
sns.countplot(data = data, y = 'Type of Employment', ax = ax[1])
sns.countplot(data = data, y = 'Profession', ax = ax[0])
ax[0].set_title('Profession Count')
ax[1].set_title('Type of Employment Count')
plt.show()

# %%
pd.crosstab(data['Profession'], data['Type of Employment']).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_b9c0d_row0_col0, #T_b9c0d_row0_col1, #T_b9c0d_row0_col2, #T_b9c0d_row0_col3, #T_b9c0d_row0_col4, #T_b9c0d_row0_col5, #T_b9c0d_row0_col6, #T_b9c0d_row0_col7, #T_b9c0d_row0_col8, #T_b9c0d_row0_col9, #T_b9c0d_row0_col10, #T_b9c0d_row0_col11, #T_b9c0d_row0_col12, #T_b9c0d_row0_col13, #T_b9c0d_row0_col14, #T_b9c0d_row0_col15, #T_b9c0d_row0_col16, #T_b9c0d_row0_col17, #T_b9c0d_row2_col13 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_b9c0d_row1_col0 {
#   background-color: #4aa466;
#   color: #f1f1f1;
# }
# #T_b9c0d_row1_col1 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_b9c0d_row1_col2, #T_b9c0d_row1_col8 {
#   background-color: #b1d866;
#   color: #000000;
# }
# #T_b9c0d_row1_col3 {
#   background-color: #7dbe66;
#   color: #000000;
# }
# #T_b9c0d_row1_col4 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_b9c0d_row1_col5 {
#   background-color: #57ab66;
#   color: #f1f1f1;
# }
# #T_b9c0d_row1_col6 {
# ...

# %%
plt.figure(figsize=(10, 15))
sns.countplot(data = data, y= 'Type of Employment', hue = 'Profession')
plt.title('Profession and Type of Employement')
plt.show()

# %% [markdown]
# #### Relation with Loan Sanction Amount

# %%
plt.figure(figsize = (18, 8))
sns.barplot(data = data, x = 'Profession', y = 'Loan Sanction Amount (USD)')
plt.title('Loan Sanction Amount predicted by Profession')
plt.show()

# %% [markdown]
# We can see that Unemployed has a very big marginal error, since the "profession" itself is very unstable

# %%
plt.figure(figsize = (18, 8))
sns.barplot(data = data, y = 'Type of Employment', x = 'Loan Sanction Amount (USD)')
#plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Location

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
data['Location'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%')
data['Location'].value_counts().plot(kind = 'bar', ax= ax[0])
plt.show()

# %% [markdown]
# #### Relation with Income & Loan Amount

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
sns.pointplot(data = data, x = 'Location', y = 'Income (USD)', ax = ax[0])
sns.pointplot(data = data, x = 'Location', y = 'Loan Sanction Amount (USD)', color = 'red')
ax[0].set_title('Location vs Income')
ax[1].set_title('Location vs Loan Amount')
plt.show()

# %% [markdown]
# Based on the graph, we can see that Location play significant role in term of Income and Loan Sanction Amount, where the higher the income, the higher Loan amount is granted

# %% [markdown]
# ### Loan Amount Request

# %%
sns.scatterplot(data = data, x = 'Loan Amount Request (USD)', y = 'Loan Sanction Amount (USD)')
plt.title('Requested amount and Sanctioned amount')
plt.show()

# %% [markdown]
# From the graph, we can se that Loan Amount Request and Loan Sanction Amount are Linear, the higher Loan Amount Request, the higher Sanction amount is

# %% [markdown]
# ### Current Loan Expense

# %%
sns.scatterplot(data = data, x = 'Current Loan Expenses (USD)', y = 'Loan Sanction Amount (USD)', hue = 'Expense Type 1')
plt.title('Requested amount and Sanctioned amount')
plt.show()

# %% [markdown]
# For Current Loan Expenses, We can see the graph is also slightly linear however, there are several data which contains - expenses

# %% [markdown]
# ### Dependents

# %%
data['Dependents'].value_counts().plot(kind = 'bar')
plt.title('Dependent Factor')
plt.show()

# %%
sns.pointplot(data = data, x = 'Dependents', y = 'Loan Sanction Amount (USD)')
plt.title('Santion Amount for Dependents')
plt.show()

# %% [markdown]
# ### Credit Score

# %%
sns.scatterplot(data = data, x = 'Credit Score', y = 'Loan Sanction Amount (USD)')
plt.title('Credit Score vs Loan Sanction Amount')
plt.show()

# %% [markdown]
# From this graph, we could see that Credit Score plays significant role for giving loan to customer, where the treshold is mostly at 650

# %% [markdown]
# ### No of Defaults

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
data['No. of Defaults'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%', explode = [0, 0.1], shadow = True, ax = ax[0])
ax[0].set_title('No of defaults distribution')
ax[0].set_ylabel('')
sns.pointplot(data = data, x ='No. of Defaults', y = 'Loan Sanction Amount (USD)')
plt.show()

# %% [markdown]
# Based on the graph, around 80% people is still manage to pay in agreed period which in result, the The one who manage to pay under agreement has a higher chance / higher loan sanction amount

# %% [markdown]
# ### Active Credit Card

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
data['Has Active Credit Card'].value_counts().plot(kind = 'pie', ax = ax[0], autopct = '%1.1f%%', explode = [0, 0.1, 0], shadow = True)
ax[0].set_title('Credit Card Status Distribution')
ax[0].set_ylabel('')
sns.pointplot(data = data, x = 'Has Active Credit Card', y = 'Loan Sanction Amount (USD)')
plt.show()

# %% [markdown]
# For credit card, Each status is slightly different (almost equal arround 30%). However, we can see that an Active Card has a higher chance to receive greater loan sanction amount.

# %% [markdown]
# ### Property ID

# %%
data['Property ID'].value_counts()
# Out:
# Property ID
# 839    51
# 870    45
# 614    44
# 944    43
# 382    43
#        ..
# 760    17
# 402    17
# 346    17
# 299    15
# 629    15
# Name: count, Length: 999, dtype: int64

# %% [markdown]
# Property ID also only represent the ID of property, thus this has no use for our Machine Learning Model

# %%
data.drop(columns=['Property ID'], inplace = True)
data
# Out:
#       Gender  Age  Income (USD) Income Stability            Profession  \
# 0          F   56       1933.05              Low               Working
# 1          M   32       4952.91              Low               Working
# 2          F   65        988.19             High             Pensioner
# 3          F   65           NaN             High             Pensioner
# 4          F   31       2614.77              Low               Working
# ...      ...  ...           ...              ...                   ...
# 29995      M   38       4969.41              Low  Commercial associate
# 29996      M   20       1606.88              Low               Working
# 29997      F   49           NaN              Low               Working
# 29998      M   38       2417.71              Low               Working
# 29999      F   63       3068.24             High             Pensioner
#
#           Type of Employment    Location  Loan Amount Request (USD)  \
# ...

# %% [markdown]
# ### Property Age

# %%
plt.subplots(1, 2, figsize = (18, 8))
sns.histplot(data = data, x ='Property Age', bins = 20)
# Out:
# <Axes: xlabel='Property Age', ylabel='Count'>

# %% [markdown]
# ### Property Type

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
data['Property Type'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%', ax = ax[0], explode = [0.1, 0, 0, 0], shadow = True)
ax[0].set_title('Property Type Distribution')
sns.pointplot(data = data, x ='Property Type', y = 'Loan Sanction Amount (USD)')
plt.show()

# %% [markdown]
# Based on the graph, we can see that although Property type 1 is the held the most at distribution, the Loan Sanction Amount is slightly bigger at Property Type 4

# %% [markdown]
# ### Property Location

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
data['Property Location'].value_counts().plot(kind = 'pie', ax = ax[0], autopct = '%1.1f%%', explode = [0.1, 0, 0], shadow = True)
ax[0].set_title('Property Location Distribution')
sns.pointplot(data = data, x= 'Property Location', y = 'Loan Sanction Amount (USD)')
plt.show()

# %% [markdown]
# As for location, Urban shows for the highest Loan Sanction Amount

# %% [markdown]
# ### Co - Applicant

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
data['Co-Applicant'].value_counts().plot(kind = 'pie', ax = ax[0], autopct = '%1.1f%%', explode = [0.1, 0, 0], shadow = True)
ax[0].set_title('Property Location Distribution')
sns.pointplot(data = data, x= 'Co-Applicant', y = 'Loan Sanction Amount (USD)')
plt.show()

# %% [markdown]
# There is an error of -999, which we will later consider it as 0, But based on the graph, the one who has Co - Applicant has a higher Sanction Amount

# %% [markdown]
# ### Property Price

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
sns.boxplot(data = data, x ='Property Price', ax = ax[0])
sns.histplot(data = data, x = 'Property Price', bins = 70, kde = True)
plt.show()

# %% [markdown]
# ## Correlation Between Features

# %%
plt.figure(figsize = (18, 8))
numerical = data.select_dtypes(include = 'number')
sns.heatmap(data = numerical.corr(), annot = True, cmap = 'coolwarm')
plt.show()

# %%
data.drop(columns = ['Loan Amount Request (USD)'], inplace = True)
data
# Out:
#       Gender  Age  Income (USD) Income Stability            Profession  \
# 0          F   56       1933.05              Low               Working
# 1          M   32       4952.91              Low               Working
# 2          F   65        988.19             High             Pensioner
# 3          F   65           NaN             High             Pensioner
# 4          F   31       2614.77              Low               Working
# ...      ...  ...           ...              ...                   ...
# 29995      M   38       4969.41              Low  Commercial associate
# 29996      M   20       1606.88              Low               Working
# 29997      F   49           NaN              Low               Working
# 29998      M   38       2417.71              Low               Working
# 29999      F   63       3068.24             High             Pensioner
#
#           Type of Employment    Location  Current Loan Expenses (USD)  \
# ...

# %% [markdown]
# # Data PreProcessing

# %% [markdown]
# ## Handling Missing Value

# %%
data.isnull().sum()
# Out:
# Gender                           52
# Age                               0
# Income (USD)                   4493
# Income Stability               1658
# Profession                        0
# Type of Employment             7188
# Location                          0
# Current Loan Expenses (USD)     167
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2446
# Credit Score                   1670
# No. of Defaults                   0
# Has Active Credit Card         1546
# Property Age                   4760
# Property Type                     0
# Property Location               347
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)        0
# dtype: int64

# %% [markdown]
# ### Profession

# %%
data['Profession'].value_counts()
# Out:
# Profession
# Working                 16739
# Commercial associate     7863
# Pensioner                2718
# State servant            2334
# Unemployed                  2
# Businessman                 2
# Student                     1
# Maternity leave             1
# Name: count, dtype: int64

# %%
threshold = 10  
category_counts = data['Profession'].value_counts()
low_frequency_categories = category_counts[category_counts < threshold].index
data = data[~data['Profession'].isin(low_frequency_categories)]

# %% [markdown]
# We need to drop Unemployed, Businessman, Student, Maternity Leeave Since the data is imbalance, hacing only 2 entry over 2000 entry with other data

# %% [markdown]
# ### Gender

# %%
data.groupby('Profession')['Gender'].apply(lambda x: x.mode().iloc[0])
# Out:
# Profession
# Commercial associate    M
# Pensioner               M
# State servant           F
# Working                 M
# Name: Gender, dtype: object

# %%
data.loc[(data['Profession']=='Commercial associate') & (data['Gender'].isna()), 'Gender'] = 'M'
data.loc[(data['Profession']=='Pensioner') & (data['Gender'].isna()), 'Gender'] = 'M'
data.loc[(data['Profession']=='State servant') & (data['Gender'].isna()), 'Gender'] = 'F'
data.loc[(data['Profession']=='Working') & (data['Gender'].isna()), 'Gender'] = 'M'

# %% [markdown]
# We Fill Missing Gender by their mode in each their profession

# %% [markdown]
# ### Income

# %%
data['Income (USD)'].groupby(data['Profession']).mean()
# Out:
# Profession
# Commercial associate    2994.456322
# Pensioner               2150.655116
# State servant           2618.707445
# Working                 2539.454077
# Name: Income (USD), dtype: float64

# %% [markdown]
# We will fill Income based on their mean of each profession.<br>
# As for Maternity leave, is for a mother takes off from work after giving work, hence its Nan meaning she did not receive any salary, we will assign it 0

# %%
data.loc[(data['Profession'] == 'Commercial associate') & (data['Income (USD)'].isna()), 'Income (USD)'] = 2994.45
data.loc[(data['Profession'] == 'Pensioner') & (data['Income (USD)'].isna()), 'Income (USD)'] = 2150.65
data.loc[(data['Profession'] == 'State servant') & (data['Income (USD)'].isna()), 'Income (USD)'] = 2618.71
data.loc[(data['Profession'] == 'Working') & (data['Income (USD)'].isna()), 'Income (USD)'] = 2539.45

# %% [markdown]
# ### Income Stability

# %%
dummy = data.dropna(subset=['Income Stability'])
dummy.groupby('Profession')['Income Stability'].apply(lambda x: x.mode().iloc[0])
# Out:
# Profession
# Commercial associate     Low
# Pensioner               High
# State servant            Low
# Working                  Low
# Name: Income Stability, dtype: object

# %%
data.loc[(data['Profession'] == 'Commercial associate') & (data['Income Stability'].isna()), 'Income Stability'] = 'Low'
data.loc[(data['Profession'] == 'Pensioner') & (data['Income Stability'].isna()), 'Income Stability'] = 'High'
data.loc[(data['Profession'] == 'State servant') & (data['Income Stability'].isna()), 'Income Stability'] = 'Low'
data.loc[(data['Profession'] == 'Working') & (data['Income Stability'].isna()), 'Income Stability'] = 'Low'

# %% [markdown]
# ### Type of Employement

# %%
data['Type of Employment'].value_counts()
# Out:
# Type of Employment
# Laborers                 5516
# Sales staff              3698
# Core staff               3188
# Managers                 2463
# Drivers                  1588
# Accountants              1363
# High skill tech staff    1297
# Medicine staff            854
# Security staff            574
# Cooking staff             561
# Cleaning staff            338
# Private service staff     337
# Secretaries               158
# Low-skill Laborers        154
# Waiters/barmen staff      148
# Realty agents              85
# IT staff                   77
# HR staff                   71
# Name: count, dtype: int64

# %%
dummy = data.dropna(subset=['Type of Employment'])
dummy.groupby('Type of Employment')['Profession'].apply(lambda x: x.mode().iloc[0])
# Out:
# Type of Employment
# Accountants              Working
# Cleaning staff           Working
# Cooking staff            Working
# Core staff               Working
# Drivers                  Working
# HR staff                 Working
# High skill tech staff    Working
# IT staff                 Working
# Laborers                 Working
# Low-skill Laborers       Working
# Managers                 Working
# Medicine staff           Working
# Private service staff    Working
# Realty agents            Working
# Sales staff              Working
# Secretaries              Working
# Security staff           Working
# Waiters/barmen staff     Working
# Name: Profession, dtype: object

# %%
data.loc[data['Type of Employment'].isna(), 'Type of Employment'] = 'Working'

# %% [markdown]
# ### Current Loan Expenses (USD)

# %%
data.groupby('Type of Employment')['Current Loan Expenses (USD)'].mean()
# Out:
# Type of Employment
# Accountants              441.080221
# Cleaning staff           333.027308
# Cooking staff            358.531946
# Core staff               392.958308
# Drivers                  428.606164
# HR staff                 444.838873
# High skill tech staff    405.529714
# IT staff                 397.310909
# Laborers                 379.730773
# Low-skill Laborers       347.418431
# Managers                 502.000347
# Medicine staff           374.113196
# Private service staff    418.804581
# Realty agents            423.813882
# Sales staff              379.910484
# Secretaries              405.522756
# Security staff           381.697211
# Waiters/barmen staff     359.486122
# Working                  393.829615
# Name: Current Loan Expenses (USD), dtype: float64

# %%
replacement_values = {
    'Accountants': 441.080221,
    'Cleaning staff': 333.027308,
    'Cooking staff': 358.531946,
    'Core staff': 392.958308,
    'Drivers': 428.606164,
    'HR staff': 444.838873,
    'High skill tech staff': 405.529714,
    'IT staff': 397.310909,
    'Laborers': 379.730773,
    'Low-skill Laborers': 347.418431,
    'Managers': 502.000347,
    'Medicine staff': 374.113196,
    'Private service staff': 418.804581,
    'Realty agents': 423.813882,
    'Sales staff': 379.910484,
    'Secretaries': 405.522756,
    'Security staff': 381.697211,
    'Waiters/barmen staff': 359.486122,
    'Working': 393.829615
}
for profession, value in replacement_values.items():
    data.loc[(data['Type of Employment'] == profession) & (data['Current Loan Expenses (USD)'].isna()), 'Current Loan Expenses (USD)'] = value
data.loc[data['Current Loan Expenses (USD)'] == -999, 'Current Loan Expenses (USD)'] = 0

# %% [markdown]
# ### Dependents

# %%
dummy = data.dropna(subset=['Dependents'])
dummy.groupby('Type of Employment')['Dependents'].apply(lambda x: x.mode().iloc[0])
# Out:
# Type of Employment
# Accountants              2.0
# Cleaning staff           2.0
# Cooking staff            2.0
# Core staff               2.0
# Drivers                  2.0
# HR staff                 2.0
# High skill tech staff    2.0
# IT staff                 2.0
# Laborers                 2.0
# Low-skill Laborers       2.0
# Managers                 2.0
# Medicine staff           2.0
# Private service staff    2.0
# Realty agents            2.0
# Sales staff              2.0
# Secretaries              2.0
# Security staff           2.0
# Waiters/barmen staff     2.0
# Working                  2.0
# Name: Dependents, dtype: float64

# %%
dummy.groupby('Profession')['Dependents'].apply(lambda x: x.mode().iloc[0])
# Out:
# Profession
# Commercial associate    2.0
# Pensioner               2.0
# State servant           2.0
# Working                 2.0
# Name: Dependents, dtype: float64

# %%
dependent_counts = data['Dependents'].value_counts()
categories_to_drop = dependent_counts[dependent_counts <= 7].index
data = data[~data['Dependents'].isin(categories_to_drop)]

# %%
data.loc[data['Dependents'].isna(), 'Dependents'] = 2.0

# %% [markdown]
# ### Credit Score

# %%
data.groupby('Type of Employment')['Credit Score'].mean()
# Out:
# Type of Employment
# Accountants              770.360177
# Cleaning staff           752.339062
# Cooking staff            724.457774
# Core staff               743.948485
# Drivers                  703.087005
# HR staff                 767.732985
# High skill tech staff    747.531169
# IT staff                 750.647286
# Laborers                 713.161579
# Low-skill Laborers       683.751611
# Managers                 757.865277
# Medicine staff           746.129391
# Private service staff    744.908523
# Realty agents            738.871325
# Sales staff              724.650906
# Secretaries              751.864830
# Security staff           720.571544
# Waiters/barmen staff     702.562044
# Working                  763.683932
# Name: Credit Score, dtype: float64

# %%
replacement_values_credit_score = {
    'Accountants': 770.360177,
    'Cleaning staff': 752.339062,
    'Cooking staff': 724.457774,
    'Core staff': 744.003126,
    'Drivers': 703.106700,
    'HR staff': 767.732985,
    'High skill tech staff': 747.497925,
    'IT staff': 750.647286,
    'Laborers': 713.161579,
    'Low-skill Laborers': 683.751611,
    'Managers': 757.865277,
    'Medicine staff': 746.129391,
    'Private service staff': 744.908523,
    'Realty agents': 738.871325,
    'Sales staff': 724.619894,
    'Secretaries': 751.864830,
    'Security staff': 720.571544,
    'Waiters/barmen staff': 702.562044,
    'Working': 763.673477
}

for profession, value in replacement_values_credit_score.items():
    data.loc[(data['Type of Employment'] == profession) & (data['Credit Score'].isna()), 'Credit Score'] = value

# %% [markdown]
# ### Active Credit Card

# %%
dummy = data.dropna(subset=['Has Active Credit Card'])
dummy.groupby('Type of Employment')['Has Active Credit Card'].apply(lambda x: x.mode().iloc[0])
# Out:
# Type of Employment
# Accountants              Unpossessed
# Cleaning staff                Active
# Cooking staff               Inactive
# Core staff                    Active
# Drivers                       Active
# HR staff                    Inactive
# High skill tech staff       Inactive
# IT staff                      Active
# Laborers                    Inactive
# Low-skill Laborers          Inactive
# Managers                      Active
# Medicine staff                Active
# Private service staff         Active
# Realty agents                 Active
# Sales staff                   Active
# Secretaries                   Active
# Security staff                Active
# Waiters/barmen staff        Inactive
# Working                       Active
# Name: Has Active Credit Card, dtype: object

# %%
replacement_values_active_card = {
    'Accountants': 'Unpossessed',
    'Cleaning staff': 'Active',
    'Cooking staff': 'Inactive',
    'Core staff': 'Active',
    'Drivers': 'Active',
    'HR staff': 'Inactive',
    'High skill tech staff': 'Inactive',
    'IT staff': 'Active',
    'Laborers': 'Inactive',
    'Low-skill Laborers': 'Inactive',
    'Managers': 'Active',
    'Medicine staff': 'Active',
    'Private service staff': 'Active',
    'Realty agents': 'Active',
    'Sales staff': 'Active',
    'Secretaries': 'Active',
    'Security staff': 'Active',
    'Waiters/barmen staff': 'Inactive',
    'Working': 'Active'
}

for profession, value in replacement_values_active_card.items():
    data.loc[(data['Type of Employment'] == profession) & (data['Has Active Credit Card'].isna()), 'Has Active Credit Card'] = value

# %% [markdown]
# ### Property Age

# %%
data.groupby('Property Type')['Property Age'].mean()
# Out:
# Property Type
# 1    2563.124787
# 2    2530.683769
# 3    2551.525093
# 4    2893.840647
# Name: Property Age, dtype: float64

# %%
data.loc[(data['Property Type'] == 1) & (data['Property Age'].isna()), 'Property Age'] = 2563.1352
data.loc[(data['Property Type'] == 2) & (data['Property Age'].isna()), 'Property Age'] = 2530.6837
data.loc[(data['Property Type'] == 3) & (data['Property Age'].isna()), 'Property Age'] = 2552.027
data.loc[(data['Property Type'] == 4) & (data['Property Age'].isna()), 'Property Age'] = 2893.8177

# %% [markdown]
# ### Property Location

# %%
dummy = data.dropna(subset=['Property Location'])
dummy.groupby('Property Type')['Property Location'].apply(lambda x: x.mode().iloc[0])
# Out:
# Property Type
# 1    Semi-Urban
# 2         Rural
# 3         Urban
# 4         Rural
# Name: Property Location, dtype: object

# %%
data.loc[(data['Property Type'] == 1) & (data['Property Location'].isna()), 'Property Location'] = 'Semi-Urban'
data.loc[(data['Property Type'] == 2) & (data['Property Location'].isna()), 'Property Location'] = 'Rural'
data.loc[(data['Property Type'] == 3) & (data['Property Location'].isna()), 'Property Location'] = 'Urban'
data.loc[(data['Property Type'] == 4) & (data['Property Location'].isna()), 'Property Location'] = 'Rurai'

# %% [markdown]
# ## Encoding Variable

# %%
data = pd.get_dummies(data, drop_first=True)
data = data.astype(float)
data
# Out:
#         Age  Income (USD)  Current Loan Expenses (USD)  Dependents  \
# 0      56.0       1933.05                       241.08         3.0
# 1      32.0       4952.91                       495.81         1.0
# 2      65.0        988.19                       171.95         1.0
# 3      65.0       2150.65                       298.54         2.0
# 4      31.0       2614.77                       491.41         2.0
# ...     ...           ...                          ...         ...
# 29995  38.0       4969.41                       722.34         2.0
# 29996  20.0       1606.88                       253.04         3.0
# 29997  49.0       2539.45                       583.11         2.0
# 29998  38.0       2417.71                       378.29         3.0
# 29999  63.0       3068.24                       693.94         1.0
#
#        Credit Score  No. of Defaults  Property Age  Property Type  \
# 0        809.440000              0.0     1933.0500            4.0
# ...

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Splitting Features and Target

# %%
X = data.drop(columns= ['Loan Sanction Amount (USD)'])
y = data['Loan Sanction Amount (USD)']

# %% [markdown]
# ## Train and Test Splitting

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train.iloc[:, [0, 1, 2, 3, 4, 6, 9]] = sc.fit_transform(X_train.iloc[:, [0, 1, 2, 3, 4, 6, 9]])
X_test.iloc[:, [0, 1, 2, 3, 4, 6, 9]] = sc.transform(X_test.iloc[:, [0, 1, 2, 3, 4, 6, 9]])

# %% [markdown]
# # Modeling

# %%
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score
def modeling(model):
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    print('Model R2Score: ', r2_score(prediction, y_test))
    score = cross_val_score(model, X_train, y_train, cv=10, scoring='accuracy')
    print('Cross Validation Score: ', score.mean())

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
linear = LinearRegression()
modeling(linear)
# Out:
# Model R2Score:  0.16152310463677566
# Cross Validation Score:  nan
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:1006: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 137, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
# ...
